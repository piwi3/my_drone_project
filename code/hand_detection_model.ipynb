# %%
import os
import time
import uuid
import cv2
import time
from djitellopy import tello

# %% [markdown]
# # Generate data

# %% [markdown]
# ## Gather images

# %%
IMAGES_PATH = os.path.join('..', 'data', 'images', 'no_hand')
number_images = 5

# %%
# Image capturing with Tello drone

me = tello.Tello()
me.connect()
print(me.get_battery())

me.streamon()

time_start = time.time() + 1
for imgnum in range(number_images):
    while True:
        img = me.get_frame_read().frame
        img = cv2.resize(img, (360, 240))
        
        if time.time() >= time_start:
            print(f'Collecting image {imgnum}')
            imgname = os.path.join(IMAGES_PATH, f'{str(uuid.uuid1())}.jpg')
            cv2.imwrite(imgname, img)
            cv2.circle(img, (180, 120), 10, (0, 255, 0), cv2.FILLED)
            break
                
        cv2.imshow("Image", img)
        cv2.waitKey(1)
    
    cv2.imshow("Image", img)
    cv2.waitKey(1)
    
    time.sleep(0.5)
    time_start = time.time() + 2
                
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

me.streamoff()
cv2.destroyAllWindows()
# Out:
# [INFO] tello.py - 122 - Tello instance was initialized. Host: '192.168.10.1'. Port: '8889'.
# [INFO] tello.py - 437 - Send command: 'command'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [415], in <cell line: 4>()
#       1 # Image capturing with Tello drone
#       3 me = tello.Tello()
# ----> 4 me.connect()
#       5 print(me.get_battery())
#       7 me.streamon()
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/djitellopy/enforce_types.py:54, in enforce_types.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      51 @wraps(func)
#      52 def wrapper(*args, **kwargs):
#      53     check_types(spec, *args, **kwargs)
# ---> 54     return func(*args, **kwargs)
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/djitellopy/tello.py:534, in Tello.connect(self, wait_for_state)
#     531 def connect(self, wait_for_state=True):
#     532     """Enter SDK mode. Call this before any of the control functions.
#     533     """
# --> 534     self.send_control_command("command")
#     536     if wait_for_state:
#     537         REPS = 20
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/djitellopy/enforce_types.py:54, in enforce_types.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      51 @wraps(func)
#      52 def wrapper(*args, **kwargs):
#      53     check_types(spec, *args, **kwargs)
# ---> 54     return func(*args, **kwargs)
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/djitellopy/tello.py:479, in Tello.send_control_command(self, command, timeout)
#     477 response = "max retries exceeded"
#     478 for i in range(0, self.retry_count):
# --> 479     response = self.send_command_with_return(command, timeout=timeout)
#     481     if 'ok' in response.lower():
#     482         return True
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/djitellopy/enforce_types.py:54, in enforce_types.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      51 @wraps(func)
#      52 def wrapper(*args, **kwargs):
#      53     check_types(spec, *args, **kwargs)
# ---> 54     return func(*args, **kwargs)
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/djitellopy/tello.py:442, in Tello.send_command_with_return(self, command, timeout)
#     438 timestamp = time.time()
#     440 client_socket.sendto(command.encode('utf-8'), self.address)
# --> 442 responses = self.get_own_udp_object()['responses']
#     444 while not responses:
#     445     if time.time() - timestamp > timeout:
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/djitellopy/enforce_types.py:54, in enforce_types.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      51 @wraps(func)
#      52 def wrapper(*args, **kwargs):
#      53     check_types(spec, *args, **kwargs)
# ---> 54     return func(*args, **kwargs)
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/djitellopy/tello.py:132, in Tello.get_own_udp_object(self)
#     129 global drones
#     131 host = self.address[0]
# --> 132 return drones[host]
#
# KeyError: '192.168.10.1'

# %% [markdown]
# ## Review images

# %%
import tensorflow as tf
import json
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img

# %%
# Avoid OOM errors by setting GPU memory consumption growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
X = []
base_path = '../data/one_class'
images_path = os.path.join(base_path, 'images')

for file in os.listdir(images_path):
                # load the image
                img = load_img(os.path.join(images_path, file))
                # convert it to an array
                img_array = np.array(img)
                # append the array to X
                X.append(img_array)

X = np.array(X)

# %%
os.path.join(base_path, 'images')
# Out:
# '../data/one_class/images'

# %%
X.shape
# Out:
# (240, 240, 360, 3)

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, image in enumerate(X[:4]):
    ax[idx].imshow(image)
plt.show()

# %% [markdown]
# ## Label images

# %% [markdown]
# _Use label me to draw boxes around all hands and mark with class name (e.g. no_hand, fist etc.)_

# %%
# !labelme
# Out:
# [INFO   ] __init__:get_config:70 - Loading config file from: /Users/philipwitte/.labelmerc

# %% [markdown]
# ## Partition unaugmented data

# %%
import random
import re

# %%
# Create 'train', 'val' and 'test' folder within 'images' and 'labels' folders:
for partition in ['train', 'val', 'test']:
    for data_type in ['images', 'labels']:
        if partition not in os.listdir(os.path.join(base_path, data_type)):
            os.mkdir(os.path.join(base_path, data_type, partition))

# %%
# Put images into regarding folders (randomly)
# First create list of all file_names
file_list = []
for file in os.listdir(os.path.join(base_path, 'images')):
    if re.findall(r'\.jpg', file):
        file_list.append(file)
len(file_list)
# Out:
# 0

# %%
#... then define sizes of datasets...
train_size = int(0.7 * len(file_list))
val_size = int(0.15 * len(file_list))
test_size = len(file_list) - train_size - val_size

train_size, val_size, test_size
# Out:
# (0, 0, 0)

# %%
# ...and finally move files randomly into target folders
for partition, sample_size in zip(['train', 'val', 'test'], [train_size, val_size, test_size]):
    selected_images = random.sample(file_list, sample_size)
    file_list = [image for image in file_list if image not in selected_images]
    for image in selected_images:
        os.rename(os.path.join(base_path, 'images', image), os.path.join(base_path, 'images', partition, image))

# %%
# Afterwards labels can be shifted accordingly
count_no_labels = 0
for partition in ['train', 'val', 'test']:
    for image in os.listdir(os.path.join(base_path, 'images', partition)):
        label_name = image[:-3] + 'json'
        try: 
            os.rename(os.path.join(base_path,'labels', label_name), 
                  os.path.join(base_path,'labels', partition, label_name))
        except:
            count_no_labels += 1
print(f'in total {count_no_labels} not found')
# Out:
# No label available for b6874222-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 2a3b73be-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for c7cce4fa-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 1fb650f8-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d2526a58-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for a83b5c5c-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d9d82ed4-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d8580610-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for b744e984-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 22b83c44-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 3dc46ff8-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 1b34d068-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for c715ccd0-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for efb1031c-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for e82b83ec-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 1e361880-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for .DS_Store
# No label available for 2d3d92cc-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 303f3c46-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d019c8d6-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 25ba5e9a-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for acbe2958-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for daa2ae44-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for b80c0894-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 2136d312-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for c4133e00-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for d9219e2c-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for bf90026e-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for f131ef76-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for c94df0f8-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 333fe620-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 4247dda8-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d555dff0-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 514fb7c6-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for a0b40d76-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for cace3852-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for cf51a1b6-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for e9acf2d2-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for d49dd3f2-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for bbc68724-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 2bbc9592-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 18327032-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for ba46170c-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for bd468a54-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for ce997c36-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for ca17bad8-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for b1421eb2-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for c5944c88-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for bec834c2-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d31d8c16-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for d19bb188-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 454883cc-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for a2362238-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 37c103a0-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d61fa7aa-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for b8c5790e-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 2438a8f6-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for bb0cab34-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 273b1610-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for ee30fbf0-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for c34a1998-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 4fcdef94-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 52d025a4-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for a6b9a5a0-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for cc5007b4-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for afc0fc02-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for cdd1a8cc-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for cd196344-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for a3b757a8-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for e6aab5d8-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for e3a90bc8-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for c2927abe-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for dda47ce4-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for b2c216a2-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 43c85338-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d0d19cda-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for eb2ede7c-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 19b3c23a-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 484a89c6-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for dc246d3e-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for ecb02922-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for b5c4be86-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 28bb56d0-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 31bf6e4c-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for bc8d772c-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 1cb577c6-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 3640b1ba-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 34bfe8ba-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for ae400062-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for a5394ea6-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 39413272-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for cb98a9c6-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for e0a661f0-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for c111f03e-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 49ca9624-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for d7a0f98a-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 3f44d606-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for ab3db3e6-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for c64b09fe-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 4b4b158c-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 2ebea924-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for be0e6fb6-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for d3d3fdc4-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for c4ca4f2c-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for b4439078-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 46c9d692-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for a9bc7476-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 4ccbdb08-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for df250b2e-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for e52a709a-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for d6d640fe-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 3ac24e42-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 40c643e8-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for e227a9e4-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for 3c434cb2-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for c8962f14-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for c0497d56-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for db59b872-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for b98c490e-e110-11ec-ae3a-8a15287fd426.jpg
# No label available for c1ca1208-e111-11ec-ae3a-8a15287fd426.jpg
# No label available for 4e4d8058-e111-11ec-ae3a-8a15287fd426.jpg

# %% [markdown]
# # Perform image augmentation

# %%
import albumentations as alb

# %% [markdown]
# ## Create augmentor with albumentation

# %%
augmentor = alb.Compose([alb.RandomBrightnessContrast(p=0.2),
                         alb.RandomGamma(p=0.2),
                         alb.RGBShift(p=0.2),
                         alb.Rotate(limit=20, p=0.2)],
                        bbox_params=alb.BboxParams(format='albumentations', 
                                                   label_fields=['class_labels']))

# %% [markdown]
# ## Use augmentor for a single image

# %%
img = cv2.imread(os.path.join(base_path, 'images', '0deefd5c-e0f3-11ec-ae3a-8a15287fd426.jpg'))

# %%
with open(os.path.join(base_path, 'labels', '0deefd5c-e0f3-11ec-ae3a-8a15287fd426.json'), 'r') as f:
    label = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [266], in <cell line: 1>()
# ----> 1 with open(os.path.join(base_path, 'labels', '0deefd5c-e0f3-11ec-ae3a-8a15287fd426.json'), 'r') as f:
#       2     label = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/one_class/labels/0deefd5c-e0f3-11ec-ae3a-8a15287fd426.json'

# %%
type(label)
# Out:
# dict

# %%
label['shapes']
# Out:
# [{'label': 'straight_hand',
#   'points': [[225.32894736842104, 103.27631578947368], [118, 0]],
#   'group_id': None,
#   'shape_type': 'rectangle',
#   'flags': {}}]

# %%
class_label = label['shapes'][0]['label']
class_label
# Out:
# 'straight_hand'

# %%
points = label['shapes'][0]['points']
points
# Out:
# [[225.32894736842104, 103.27631578947368], [118, 0]]

# %%
cv2.rectangle(img,
              tuple([int(i) for i in points[0]]),
              tuple([int(i) for i in points[1]]),
              (255, 0, 0), 2)

plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [271], in <cell line: 6>()
#       1 cv2.rectangle(img,
#       2               tuple([int(i) for i in points[0]]),
#       3               tuple([int(i) for i in points[1]]),
#       4               (255, 0, 0), 2)
# ----> 6 plt.imshow(img)
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/matplotlib/pyplot.py:2645, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2638 @docstring.copy(Axes.imshow)
#    2639 def imshow(
#    2640         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    (...)
#    2643         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2644         resample=None, url=None, *, data=None, **kwargs):
# -> 2645     __ret = gca().imshow(
#    2646         X, cmap=cmap, norm=norm, aspect=aspect,
#    2647         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2648         vmax=vmax, origin=origin, extent=extent, shape=shape,
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
#    2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/matplotlib/__init__.py:1565, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1562 @functools.wraps(func)
#    1563 def inner(ax, *args, data=None, **kwargs):
#    1564     if data is None:
# -> 1565         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1567     bound = new_sig.bind(ax, *args, **kwargs)
#    1568     auto_label = (bound.arguments.get(label_namer)
#    1569                   or bound.kwargs.get(label_namer))
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/matplotlib/cbook/deprecation.py:358, in _delete_parameter.<locals>.wrapper(*args, **kwargs)
#     352 if name in arguments and arguments[name] != _deprecated_parameter:
#     353     warn_deprecated(
#     354         since, message=f"The {name!r} parameter of {func.__name__}() "
#     355         f"is deprecated since Matplotlib {since} and will be removed "
#     356         f"%(removal)s.  If any parameter follows {name!r}, they "
#     357         f"should be pass as keyword, not positionally.")
# --> 358 return func(*args, **kwargs)
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/matplotlib/cbook/deprecation.py:358, in _delete_parameter.<locals>.wrapper(*args, **kwargs)
#     352 if name in arguments and arguments[name] != _deprecated_parameter:
#     353     warn_deprecated(
#     354         since, message=f"The {name!r} parameter of {func.__name__}() "
#     355         f"is deprecated since Matplotlib {since} and will be removed "
#     356         f"%(removal)s.  If any parameter follows {name!r}, they "
#     357         f"should be pass as keyword, not positionally.")
# --> 358 return func(*args, **kwargs)
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5626, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5621 self.set_aspect(aspect)
#    5622 im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5623                       filternorm=filternorm, filterrad=filterrad,
#    5624                       resample=resample, **kwargs)
# -> 5626 im.set_data(X)
#    5627 im.set_alpha(alpha)
#    5628 if im.get_clip_path() is None:
#    5629     # image does not already have clipping set, clip to axes patch
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/matplotlib/image.py:693, in _ImageBase.set_data(self, A)
#     689 self._A = cbook.safe_masked_invalid(A, copy=True)
#     691 if (self._A.dtype != np.uint8 and
#     692         not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 693     raise TypeError("Image data of dtype {} cannot be converted to "
#     694                     "float".format(self._A.dtype))
#     696 if not (self._A.ndim == 2
#     697         or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     698     raise TypeError("Invalid shape {} for image data"
#     699                     .format(self._A.shape))
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
# Convert coordinates into a one-dimensional list
coords = []
for coord_list in points:
    for coord in coord_list:
        coords.append(coord)
coords

# %%
# Convert into 'alubmentations' format, i.e. relative to img dimensions
coords = list(np.divide(coords, [360, 240, 360, 240]))
coords

# %%
# Augment image using the defined augmentor
augmented = augmentor(image=img, bboxes=[coords], class_labels=['straight_hand'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [272], in <cell line: 2>()
#       1 # Augment image using the defined augmentor
# ----> 2 augmented = augmentor(image=img, bboxes=[coords], class_labels=['straight_hand'])
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/albumentations/core/composition.py:195, in Compose.__call__(self, force_apply, *args, **data)
#     193     raise KeyError("You have to pass data to augmentations as named arguments, for example: aug(image=image)")
#     194 if self.is_check_args:
# --> 195     self._check_args(**data)
#     196 assert isinstance(force_apply, (bool, int)), "force_apply must have bool or int type"
#     197 need_to_run = force_apply or random.random() < self.p
#
# File /opt/miniforge3/envs/tello_ai/lib/python3.9/site-packages/albumentations/core/composition.py:271, in Compose._check_args(self, **kwargs)
#     269 if internal_data_name in checked_single:
#     270     if not isinstance(data, np.ndarray):
# --> 271         raise TypeError("{} must be numpy array type".format(data_name))
#     272 if internal_data_name in checked_multi:
#     273     if data:
#
# TypeError: image must be numpy array type

# %%
# Output is a dictionary
type(augmented)
# Out:
# dict

# %%
# Image, bbox and class labels are keys
augmented.keys()
# Out:
# dict_keys(['image', 'bboxes', 'class_labels'])

# %%
# Draw augmented image incl. bbox
cv2.rectangle(augmented['image'],
              tuple(np.multiply(augmented['bboxes'][0][:2], [360, 240]).astype(int)),
              tuple(np.multiply(augmented['bboxes'][0][2:], [360, 240]).astype(int)),
              (255, 0, 0), 2)

plt.imshow(augmented['image'])

# %% [markdown]
# ## Perform augmentation and partition data

# %%
# Create new directories for augmented images and labels
try:
    os.mkdir(os.path.join(base_path, 'augmented'))
except:
    print('augmented folder already exists.')

for data_type in ['images', 'labels']:
    try:
        os.mkdir(os.path.join(base_path, 'augmented', data_type))
    except:
        print(f'{data_type} folder exists already.')
    for partition in ['train', 'val', 'test']:
        try:
            os.mkdir(os.path.join(base_path, 'augmented', data_type, partition))
        except:
            print(f'{partition} folder within {data_type} exists already.')
# Out:
# augmented folder already exists.
# images folder exists already.
# train folder within images exists already.
# val folder within images exists already.
# test folder within images exists already.
# labels folder exists already.
# train folder within labels exists already.
# val folder within labels exists already.
# test folder within labels exists already.

# %%
# Augment images and save in regarding folders augemneted/images and augmented/labels
for partition in ['train', 'val', 'test']:
    partition_dir = os.path.join(base_path, 'images', partition)
    for image_name in os.listdir(partition_dir):
      
        # Load image
        image = cv2.imread(os.path.join(partition_dir, image_name))
        
        # In case no label is available, coordinates and class_label are predefined
        class_label = 'no_hand'
        coords = [0, 0, 0.00001, 0.00001] # x_max / y_max need to be > 0 for augmentor!
        
        # Load label (if exists) and get coordinates of box & class_name
        label_path = os.path.join(base_path, 'labels', partition, image_name[:-3] + 'json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)
            
            # Get class name
            class_label = label['shapes'][0]['label']
            
            # Get coordinates of bbox and scale them
            i = 0    
            for coord_list in label['shapes'][0]['points']:
                for coord in coord_list:
                    coords[i] = coord
                    i += 1
            coords = list(np.divide(coords, [360, 240, 360, 240]))
            
            # Change points, if max point is saved in first position
            if coords[0] > coords[2]:
                coords = coords[-2:] + coords[:2]
        
        # Save augmented image and annotation file
        try:
            for i in range(20):
                # Utilize augmentor
                augmented = augmentor(image = image, bboxes=[coords], class_labels=[class_label])
        
                # Save image
                image_name_new = os.path.join(base_path, 'augmented', 'images', partition, 
                                         image_name[:-3] + f'{i}' + '.jpg')
                cv2.imwrite(image_name_new, augmented['image'])
                
    
                # Create annotation
                annotation = {}
                annotation['image'] = image_name_new
                
                annotation['bbox'] = [0, 0, 0, 0]
                annotation['class'] = 0                    ### potentially to be replaced with class_label!!!
                
                if os.path.exists(label_path):
                    annotation['bbox'] = list(augmented['bboxes'][0])
                    annotation['class'] = 1                ### potentially to be replaced with class_label!!!
                    
                # Save annotations
                with open(os.path.join(base_path, 'augmented', 'labels', partition, 
                                       image_name[:-3] + f'{i}' + '.json'), 'w') as f:
                    json.dump(annotation, f)
        
        except Exception as e:
            print(e)
            
# Comment: Labelme saves first click as x_min and second click as x_max. That means if the rectangle has been 
# drawn from right bottom corner to left top corner a error message will be sent by augmentor
# Out:
# image must be numpy array type

# %% [markdown]
# ## Build augmentation pipeline (tf.dataset)

# %%
# Load image from file
def load_img(jpeg_file):
    byte_img = tf.io.read_file(jpeg_file)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %%
# Create tf dataset from images
X = []
for partition in ['train', 'val', 'test']:
    
    # Create a dataset of all files matching a pattern
    X_i = tf.data.Dataset.list_files(os.path.join(base_path, 'augmented', 'images', partition, '*.jpg'), 
                                         shuffle=False)
    # Read file and decode into jpeg format
    X_i = X_i.map(load_img)
    
    # Save in list 
    X.append(X_i)

X_train = X[0]
X_val = X[1]
X_test = X[2]

# %%
type(X_train)
# Out:
# tensorflow.python.data.ops.dataset_ops.MapDataset

# %%
X_train.as_numpy_iterator().next()
# Out:
# array([[[198, 203, 180],
#         [199, 204, 181],
#         [199, 204, 181],
#         ...,
#         [177, 196, 168],
#         [177, 196, 168],
#         [176, 195, 167]],
#
#        [[197, 202, 179],
#         [198, 203, 180],
#         [199, 204, 181],
#         ...,
#         [177, 196, 168],
#         [176, 195, 167],
#         [176, 195, 167]],
#
#        [[196, 201, 178],
#         [197, 202, 179],
#         [199, 204, 181],
#         ...,
#         [177, 196, 168],
#         [176, 195, 167],
#         [176, 195, 167]],
#
#        ...,
#
#        [[143, 120,  76],
#         [144, 121,  77],
#         [143, 120,  78],
#         ...,
#         [ 93, 117, 104],
#         [ 89, 112, 102],
#         [ 84, 107,  97]],
#
#        [[148, 125,  83],
#         [145, 122,  80],
#         [142, 119,  77],
#         ...,
#         [ 56,  82,  73],
#         [ 56,  81,  75],
#         [ 54,  79,  73]],
#
#        [[148, 125,  83],
#         [147, 124,  82],
#         [145, 122,  80],
#         ...,
#         [ 49,  74,  68],
#         [ 49,  74,  70],
#         [ 46,  71,  67]]], dtype=uint8)

# %%
# Function to load json files
def load_labels(label_path):
    with open(label_path.numpy(), 'r', encoding='utf-8') as f:
        label = json.load(f)
        
    return [label['class']], label['bbox']

# %%
# Create tf dataset for labels
y = []
for partition in ['train', 'val', 'test']:
    # Create a dataset of all files matching a pattern
    y_i = tf.data.Dataset.list_files(os.path.join(base_path, 'augmented', 'labels', partition, '*.json'), 
                                         shuffle=False)
    
    # Read file and decode into jpeg format (py_function wraps a python function into a TensorFlow op)
    y_i = y_i.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))
    
    # Save in list 
    y.append(y_i)

y_train = y[0]
y_val = y[1]
y_test = y[2]

# %%
type(y_train)
# Out:
# tensorflow.python.data.ops.dataset_ops.MapDataset

# %%
y_train.as_numpy_iterator().next()
# Out:
# (array([1], dtype=uint8),
#  array([0.4568, 0.1086, 0.573 , 0.3342], dtype=float16))

# %%
len(X_train), len(y_train), len(X_val), len(y_val), len(X_test), len(y_test)
# Out:
# (3360, 3360, 720, 720, 720, 720)

# %%
# Create final dataset by zipping images and labels
data = []
for X, y in zip([X_train, X_val, X_test], [y_train, y_val, y_test]):
    # Zip data together
    data_i = tf.data.Dataset.zip((X, y))
    # Shuffle images
    data_i = data_i.shuffle(4000)
    # Batch contains 8 images + labels
    data_i = data_i.batch(8)
    # Prefetch helps eliminate bottlenecks
    data_i = data_i.prefetch(4)
    
    data.append(data_i)
    
data_train = data[0]
data_val = data[1]
data_test = data[2]

# %%
# Expected: 8 images, 240*360, 3 channels
data_train.as_numpy_iterator().next()[0].shape
# Out:
# (8, 240, 360, 3)

# %% [markdown]
# ## Review augmented images and bboxes

# %%
data_samples = data_train.as_numpy_iterator()

# %%
res = data_samples.next()

fig, ax = plt.subplots(ncols=4, figsize=(18, 12))

for idx in range(4):
    sample_image = res[0][idx]
    sample_coords = res[1][1][idx]
    #print(res)
    
    cv2.rectangle(sample_image,
                  tuple(np.multiply(sample_coords[:2], [360, 240]).astype(int)),
                  tuple(np.multiply(sample_coords[2:], [360, 240]).astype(int)),
                  (255,0,0), 2)
    
    ax[idx].imshow(sample_image)

# %% [markdown]
# # Build neuronal network

# %%
from tensorflow.keras.layers import Resizing, Rescaling
from tensorflow.keras import Sequential

# %%
# Define preprocessing layer
preprocessing = Sequential([
  Resizing(120, 120),
  Rescaling(1./255)
])
